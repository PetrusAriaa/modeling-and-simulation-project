# %%
import matplotlib.pyplot as plt
import numpy as np
from ant import Ant

# %%
myAnt = Ant(shape=(50,50), edge=1)
myAnt.summon(ant_prob=.5)
ant_map = myAnt.ant_map()
fig = plt.imshow(ant_map, cmap='Reds')

# %%
from copy import deepcopy

ant_grid = np.zeros((7, 7, 3))
ant_grid[:,:,0] = deepcopy(ant_map)
ant_grid
